# %%
from pjs_qlab.data.YahooPriceFetcher import YahooPriceFetcher as price_fetcher
from pjs_qlab.data.cYahoo_API import

# %%
tickers=['AAPL','GOOG','AMZN','META']
period='max'

# %%
hlc=price_fetcher(tickers, period=period)

# %%
hlc.get_close()
# Out:
# [*********************100%***********************]  4 of 4 completed
# Ticker            AAPL        AMZN        GOOG        META
# Date
# 2012-05-18   15.891776   10.692500   14.842628   37.964802
# 2012-05-21   16.817633   10.905500   15.181555   33.793934
# 2012-05-22   16.688501   10.766500   14.852515   30.784956
# 2012-05-23   17.095697   10.864000   15.066600   31.778019
# 2012-05-24   16.938683   10.762000   14.923219   32.800873
# ...                ...         ...         ...         ...
# 2026-02-26  272.950012  207.919998  307.149994  657.010010
# 2026-02-27  264.179993  210.000000  311.429993  648.179993
# 2026-03-02  264.720001  208.389999  306.359985  653.559998
# 2026-03-03  263.750000  208.729996  303.559998  655.080017
# 2026-03-04  262.519989  216.820007  303.450012  667.729980
#
# [3467 rows x 4 columns]
